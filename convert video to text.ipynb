# %%
# !pip install moviepy
# Out:
# ...
#                                               0.0/388.3 kB ? eta -:--:--
#      ---                                   41.0/388.3 kB 991.0 kB/s eta 0:00:01
#      ---------                               92.2/388.3 kB 1.1 MB/s eta 0:00:01
#      ------------                           122.9/388.3 kB 1.0 MB/s eta 0:00:01
#      ------------                           122.9/388.3 kB 1.0 MB/s eta 0:00:01
#      ----------------                     174.1/388.3 kB 700.2 kB/s eta 0:00:01
#      ----------------------               245.8/388.3 kB 942.1 kB/s eta 0:00:01
#      --------------------------           286.7/388.3 kB 842.9 kB/s eta 0:00:01
#      -------------------------------      337.9/388.3 kB 952.6 kB/s eta 0:00:01
#      ------------------------------------ 388.3/388.3 kB 895.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#                                               0.0/22.6 MB ? eta -:--:--
# ...

# %%
# !pip install SpeechRecognition
# Out:
# ...
#                                               0.0/32.8 MB ? eta -:--:--
#                                               0.0/32.8 MB 1.3 MB/s eta 0:00:26
#                                               0.1/32.8 MB 1.1 MB/s eta 0:00:29
#                                               0.1/32.8 MB 1.0 MB/s eta 0:00:32
#                                               0.1/32.8 MB 1.1 MB/s eta 0:00:31
#                                               0.1/32.8 MB 1.1 MB/s eta 0:00:31
#                                              0.3/32.8 MB 923.9 kB/s eta 0:00:36
#                                               0.3/32.8 MB 1.0 MB/s eta 0:00:33
#                                              0.4/32.8 MB 998.3 kB/s eta 0:00:33
#                                               0.4/32.8 MB 1.0 MB/s eta 0:00:33
#                                               0.4/32.8 MB 1.0 MB/s eta 0:00:33
#                                              0.5/32.8 MB 880.6 kB/s eta 0:00:37
# ...

# %%
# !pip install pyaudio
# Out:
# ...
#                                               0.0/164.1 kB ? eta -:--:--
#      ---------                             41.0/164.1 kB 960.0 kB/s eta 0:00:01
#      ---------------------                   92.2/164.1 kB 1.0 MB/s eta 0:00:01
#      -------------------------------      143.4/164.1 kB 944.1 kB/s eta 0:00:01
#      ------------------------------------ 164.1/164.1 kB 979.8 kB/s eta 0:00:00
# ...

# %%
from moviepy.editor import *
import speech_recognition as sr

# %%
video = VideoFileClip("ai1.mp4")

# %%
audio = video.audio
audio.write_audiofile("ai1.wav")
# Out:
# MoviePy - Writing audio in ai1.wav
# MoviePy - Done.

# %%
recognizer = sr.Recognizer()

# %%
with sr.AudioFile("ai1.wav") as source:
    audio_data = recognizer.record(source)
    text = recognizer.recognize_google(audio_data)
    print(text)
# Out:
# when you hear the term artificial intelligence what comes to mind super-powered robots hyper-intelligent devices science fiction has familiarized the world with the concept but outside of Hollywood what is artificial intelligence and what can AI actually do for starters AI involves using computers to do things that usually require human intelligence humans can see what their eyes and process what they see we can understand our environments and move around within them our brains have the ability to see patterns and we have the ability to understand spoken language artificial intelligence is a broad branch of computer science that includes many different terms in order for computers to achieve these capabilities they require lots and lots of data large data sets allow AI algorithms to identify patterns make predictions and recommend actions artificial intelligence is already all around us but today's best AI still can't compete with the human brain in some ways for example in 2016 the 
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#                                               0.0/55.1 kB ? eta -:--:--
#      ---------------------                  30.7/55.1 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 55.1/55.1 kB 712.1 kB/s eta 0:00:00
# ...
#                                               0.0/1.5 MB ? eta -:--:--
#                                               0.0/1.5 MB 1.3 MB/s eta 0:00:02
#      -                                        0.1/1.5 MB 1.1 MB/s eta 0:00:02
#      -                                        0.1/1.5 MB 1.1 MB/s eta 0:00:02
#      --                                       0.1/1.5 MB 655.4 kB/s eta 0:00:03
#      -----                                    0.2/1.5 MB 1.1 MB/s eta 0:00:02
#      ------                                   0.2/1.5 MB 1.1 MB/s eta 0:00:02
#      -------                                  0.3/1.5 MB 1.1 MB/s eta 0:00:02
# ...

# %%
# !pip install deep-translator
# Out:
# ...
#                                               0.0/42.3 kB ? eta -:--:--
#      -----------------------------            30.7/42.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 42.3/42.3 kB 681.8 kB/s eta 0:00:00
# ...

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
# Assuming 'text' contains the English text extracted from the speech recognition
translated_text = translator.translate(text, src='en', dest='fr').text

print("Translated text in French:", translated_text)
# Out:
# Translated text in French: Lorsque vous entendez le terme intelligence artificielle, ce qui vient à l'esprit des robots super-alimentés des appareils hyper-intelligents La science-fiction a familiarisé le monde avec le concept, mais en dehors de Hollywood, ce qui est l'intelligence artificielle et ce que AI peut réellement faire pour les démarreurs, AI implique l'utilisation d'ordinateurs à faire pour faireLes choses qui nécessitent généralement l'intelligence humaine que les humains peuvent voir ce que leurs yeux et traiter ce qu'ils voient, nous pouvons comprendre nos environnements et se déplacer en eux, nos cerveaux ont la capacité de voir des modèles et nous avons la capacité de comprendre l'intelligence artificielle parlée la langue est une large branchede l'informatique qui comprend de nombreux termes différents pour que les ordinateurs atteignent ces capacités, ils nécessitent beaucoup et beaucoup de données de grandes ensembles de données permettent aux algorithmes d'IA d'id
# ...

# %%
# Assuming 'text' contains the English text extracted from the speech recognition
translated_text = translator.translate(text, src='en', dest='ar').text

print("Translated text in Arabic:", translated_text)
# Out:
# Translated text in Arabic: عندما تسمع مصطلح الذكاء الاصطناعي ، فإن ما يتبادر إلى الذهن الروبوتات الروبوتات المفرطة ذات النطق المفرط في أن الخيال العلمي قد تعرف على العالم بالمفهوم ، لكن خارج هوليوود ما هو الذكاء الاصطناعي وما الذي يمكن أن تفعله الذكاء الاصطناعى في الواقع من أجل المبتدئين منظمة العفو الدولية ينطوي على استخدام أجهزة الكمبيوتر لفعلالأشياء التي تتطلب عادة الذكاء البشري يمكن أن يرى البشر ما يعالجونه ما يرون أنه يمكننا أن نفهم بيئاتنا والتحرك داخلهم أدمغتنا لديها القدرة على رؤية الأنماط ولدينا القدرة على فهم اللغة المنطوقة الذكاء الاصطناعي هي فرع واسعمن علوم الكمبيوتر التي تتضمن العديد من المصطلحات المختلفة من أجل تحقيق أجهزة الكمبيوتر هذه القدرات التي تتطلبها الكثير والكثير من البيانات ، تتيح مجموعات البيانات الكبيرة خوارزميات الذكاء الاصطناعى تحديد أنماط تجعل التنبؤيتنافس مع الدماغ البشري في بعض النواحي على سبيل المثال في عام 2016 ، هزم برنامج الكمبيوتر Alphago لاعب غولف محترف أسطوري ، لكن إذا طلبت من نفس الكمبيوتر قيادة سيارة أو حتى لعب الاحتكار ، فلن يكون قادرًا على ال
# ...
